# %%
#to get ascii values of a character use ord() function

# %%
ord("A")
# Out:
# 65

# %%
ord("Z")
# Out:
# 90

# %%
ord("!")
# Out:
# 33

# %%
ord("@")
# Out:
# 64

# %%
ord(" ")
# Out:
# 32

# %%
name="Rajveer Gupta"

# %%
for i in name:
    print(i, " ", ord(i))
# Out:
# R   82
# a   97
# j   106
# v   118
# e   101
# e   101
# r   114
#     32
# G   71
# u   117
# p   112
# t   116
# a   97

# %%
[ord(c har) for char in name]
# Out:
# [82, 97, 106, 118, 101, 101, 114, 32, 71, 117, 112, 116, 97]
